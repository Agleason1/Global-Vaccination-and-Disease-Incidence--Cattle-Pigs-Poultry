# %% [markdown]
# ## Kernel to load: vax_inc_general

# %%
import pandas as pd
import numpy as np
from scipy.stats import binomtest
from functools import reduce
import random
import pycountry
import os
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
notebook_dir = os.path.dirname(os.getcwd())
source_data_path=os.path.join(notebook_dir, "Common Source Data")

# %%
df_start= pd.read_csv(os.path.join(source_data_path, 'poultry/AllRegions_Poultry_MoreVaccinationData.csv'))
df_start=df_start[df_start['Semester']!='Jul-Dec 2024']
df_start['Disease']=[i if i!= 'Newcastle disease virus (Inf. with)' else 'Newcastle disease (velogenic)' for i in df_start['Disease']]
df_start
# Out:
#        Year      Semester  Region          Country  \
# 0      2005  Jul-Dec 2005    Asia      Afghanistan
# 1      2005  Jul-Dec 2005  Europe          Albania
# 2      2005  Jul-Dec 2005  Africa          Algeria
# 3      2005  Jul-Dec 2005  Africa          Algeria
# 4      2005  Jul-Dec 2005  Africa          Algeria
# ...     ...           ...     ...              ...
# 12381  2024  Jan-Jun 2024  Africa       Mozambique
# 12382  2024  Jan-Jun 2024  Europe      Netherlands
# 12383  2024  Jan-Jun 2024  Europe  North Macedonia
# 12384  2024  Jan-Jun 2024    Asia            Syria
# 12385  2024  Jan-Jun 2024    Asia            Syria
#
#                                            Disease Animal category Species  \
# 0                    Newcastle disease (velogenic)        Domestic   Birds
# 1                    Newcastle disease (velogenic)        Domestic   Birds
# 2                      Avian infectious bronchitis        Domestic   Birds
# 3                                 Fowl pox (-2005)        Domestic   Birds
# 4      Infectious bursal disease (Gumboro disease)        Domestic   Birds
# ...                                            ...             ...     ...
# 12381                Newcastle disease (velogenic)        Domestic   Birds
# 12382                Newcastle disease (velogenic)        Domestic   Birds
# 12383                Newcastle disease (velogenic)        Domestic   Birds
# 12384                Newcastle disease (velogenic)        Domestic   Birds
# 12385                Newcastle disease (velogenic)        Domestic   Birds
#
#                   Vaccine type Number of vaccinated
# 0                            -                95574
# 1                            -              2046783
# 2                            -                    -
# 3                            -                    -
# 4                            -                    -
# ...                        ...                  ...
# 12381                        -                    -
# 12382                        -                    -
# 12383                        -                    -
# 12384  Live Attenuated Vaccine              1511265
# 12385                        -                    -
#
# [12386 rows x 9 columns]

# %%
# List of diseases where no vaccine exists
diseases_no_vaccine = [
    "African cattle fever virus (Inf. with)",
    "Avian tuberculosis (-2005)",
    "Bovine spongiform encephalopathy",
    "Crimean Congo haemorrhagic fever (2006-)",
    "Maedi-visna",
    "Malignant catarrhal fever (wildebeest only)(2006-2008)",
    "New world screwworm (Cochliomyia hominivorax)",
    "Nipah virus encephalitis",
    "Scrapie",
    "Surra (Trypanosoma evansi)",
    "Theileria equi and Babesia caballi (Inf. with) (Equine piroplasmosis)",
    "Tularemia"
]

# %%
records_edited = 0
diseases_found = []
removed_records = []  

# Iterate through diseases and remove invalid records
for disease in diseases_no_vaccine:
    if disease in df_start['Disease'].unique():
        diseases_found.append(disease)  
        condition = (df_start['Disease'] == disease)
        
        disease_removed_records = df_start[condition]
        removed_records.append(disease_removed_records)
        
        count_disease_edits = disease_removed_records.shape[0]
        records_edited += count_disease_edits
        
        df_start = df_start[~condition]

print(f"Total records edited (removed): {records_edited}")

if diseases_found:
    print("\nDiseases with removed vaccination records:")
    for d in diseases_found:
        print(f" - {d}")
else:
    print("\nNone of the specified diseases were found in the dataframe.")

if removed_records:
    print("\nDetails of removed records:")
    for i, records in enumerate(removed_records):
        print(f"\nRemoved records for disease: {diseases_found[i]}")
        print(records)
else:
    print("\nNo records were removed.")

df_start.reset_index(drop=True, inplace=True)
print("\nFinal dataframe shape:", df_start.shape)
# Out:
# Total records edited (removed): 3
#
# Diseases with removed vaccination records:
#  - Avian tuberculosis (-2005)
#
# Details of removed records:
#
# Removed records for disease: Avian tuberculosis (-2005)
#      Year      Semester  Region     Country                     Disease  \
# 235  2005  Jul-Dec 2005    Asia  Kazakhstan  Avian tuberculosis (-2005)
# 683  2005  Jan-Jun 2005    Asia  Kazakhstan  Avian tuberculosis (-2005)
# 713  2005  Jan-Jun 2005  Europe   Lithuania  Avian tuberculosis (-2005)
#
#     Animal category Species Vaccine type Number of vaccinated
# 235        Domestic   Birds            -                    -
# 683        Domestic   Birds            -                99100
# 713        Domestic   Birds            -                19866
#
# Final dataframe shape: (12383, 9)

# %%
df_part_full=pd.read_csv('2005-2024_part_poultry_vaccine_coverage_by_country.csv')
df_part_full['Disease']=[i if i!= 'Newcastle disease virus (Inf. with)' else 'Newcastle disease' for i in df_part_full['Disease']]

# %%
dict_dates = dict({
                  'Jan-Jun 2005':'2005-06-30','Jul-Dec 2005':'2005-12-31',
                  'Jan-Jun 2006':'2006-06-30','Jul-Dec 2006':'2006-12-31',
                  'Jan-Jun 2007':'2007-06-30','Jul-Dec 2007':'2007-12-31',
                  'Jan-Jun 2008':'2008-06-30','Jul-Dec 2008':'2008-12-31',
                  'Jan-Jun 2009':'2009-06-30','Jul-Dec 2009':'2009-12-31',
                  'Jan-Jun 2010':'2010-06-30','Jul-Dec 2010':'2010-12-31',
                  'Jan-Jun 2011':'2011-06-30','Jul-Dec 2011':'2011-12-31',
                  'Jan-Jun 2012':'2012-06-30','Jul-Dec 2012':'2012-12-31',
                  'Jan-Jun 2013':'2013-06-30','Jul-Dec 2013':'2013-12-31',
                  'Jan-Jun 2014':'2014-06-30','Jul-Dec 2014':'2014-12-31',
                  'Jan-Jun 2015':'2015-06-30','Jul-Dec 2015':'2015-12-31',
                  'Jan-Jun 2016':'2016-06-30','Jul-Dec 2016':'2016-12-31',
                  'Jan-Jun 2017':'2017-06-30','Jul-Dec 2017':'2017-12-31',
                  'Jan-Jun 2018':'2018-06-30','Jul-Dec 2018':'2018-12-31',
                  'Jan-Jun 2019':'2019-06-30','Jul-Dec 2019':'2019-12-31',
                  'Jan-Jun 2020':'2020-06-30','Jul-Dec 2020':'2020-12-31',
                  'Jan-Jun 2021':'2021-06-30','Jul-Dec 2021':'2021-12-31',
                  'Jan-Jun 2022':'2022-06-30','Jul-Dec 2022':'2022-12-31',
                  'Jan-Jun 2023':'2023-06-30','Jul-Dec 2023':'2023-12-31',
                  'Jan-Jun 2024':'2024-06-30'

                                                                        })

df_start=df_start.copy()

df_start['time']=[dict_dates[i] for i in df_start['Semester']]
df_start['Semester']=['June' if '06-30' in time else 'December' for time in df_start['time'].values]
df_start['time'] = pd.to_datetime(df_start['time'])

# %%
df_start['Number of vaccinated'] = [
    float(i) if i != '-' else None for i in df_start['Number of vaccinated']
]

df_start = df_start[df_start['Number of vaccinated'] >= 0].copy()

# %%
start_countries=df_start['Country']

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_3
    countries['USA']='USA'
    countries['UK']='GBR'
    countries['Taiwan']='TWN'
    countries['South Korea']='KOR'
    countries['Czech Republic']='CZE'
    countries['Brunei']='BRN'
    countries['Russia']='RUS'
    countries['Iran']='IRN'
    countries['United States of America']='USA'
    countries['Venezuela']='VEN'
    countries['China (Hong Kong SAR)']='HKG'
    countries["Cote d'Ivoire"]='CIV'
    countries['DR Congo']='COD'
    countries['Guinea Bissau']='GNB'
    countries['Lao PDR']='LAO'
    countries['Micronesia (Federated States of)']='FSM'
    countries['North Korea']='PRK'
    countries['Occupied Palestinian Territory']='PSE'
    countries['Swaziland']='SWZ'
    countries['Tanzania']='TZA'
    countries['Bolivia']='BOL'
    countries['Macedonia (TFYR)']='MKD'
    countries['Moldova']='MDA'
    countries['Bolivia (Plurinational State of)']='BOL'
    countries['China, Hong Kong SAR']='HKG'
    countries['China, Taiwan Province of']='TWN'
    countries['China, mainland']='CHN'
    countries['Czechoslovakia']='CSK'
    countries["Democratic People's Republic of Korea"]='PRK'
    countries['Democratic Republic of the Congo']='COD'
    countries['French Guyana']='GUF'
    countries['Micronesia']='FSM'
    countries['Palestine']='PSE'
    countries['Polynesia']='PYF'
    countries['Republic of Korea']='KOR'
    countries['Serbia and Montenegro']='SCG'
    countries['Sudan (former)']='SDN'
    countries['Türkiye']='TUR'
    countries['USSR']='SUN'
    countries['Iran (Islamic Republic of)']='IRN'
    countries['Republic of Moldova']='MDA'
    countries['United Kingdom of Great Britain and Northern Ireland']='GBR'
    countries['United Republic of Tanzania']='TZA'
    countries['Venezuela (Bolivarian Republic of)']='VEN'
    countries['Yugoslav SFR']='YUG'
    countries['Ethiopia PDR']='ETH'
    countries['Central African (Rep.)']='CAF'
    countries["China (People's Rep. of)"]='CHN'
    countries['Chinese Taipei']='TWN'
    countries['Congo (Dem. Rep. of the)']='COD'
    countries['Congo (Rep. of the)']='COG'
    countries["Cote D'Ivoire"]='CIV'
    countries['Dominican (Rep.)']='DOM'
    countries["Korea (Dem People's Rep. of)"]='PRK'
    countries['Korea (Rep. of)']='KOR'
    countries['Laos']='LAO'
    countries['South Sudan (Rep. of)']='SSD'
    countries['Syria']='SYR'
    countries['St. Vincent and the Grenadines']='VCT'
    countries['Vietnam']='VNM'
    countries['Reunion']='REU'
    countries['Guadaloupe']='GLP'
    countries['China, Macao SAR']='MAC'
    countries['Netherlands (Kingdom of the)']='NLD'
    countries['Türkiye (Rep. of)']='TUR'
    countries['Belgium-Luxembourg']='BLX'
    countries['Faeroe Islands']='FRO'
    countries['Cabo verde']='CPV'
    countries['St. Helena']='SHN'

    

codes_start=[countries.get(country, 'Unknown code:'+country) for country in start_countries]

for code in codes_start:
    if "Unknown" in code:
        print("FIX THIS:",code)


iso3s_start=[]

for i in start_countries:
    try:
        iso3s_start+=[countries[i]]
    except:
        iso3s_start+=[None]
        
df_start['ISO3']=iso3s_start

# %%
 # Aggregate rows by 'Country', 'Disease', and 'Year' to sum 'Number of vaccinated'
df_start = df_start.groupby(['Year', 'Country', 'Disease'], as_index=False).agg({
    'ISO3': 'first',
    'Country': 'first',
    'Year': 'first',
    'Region': 'first',
    'Disease': 'first',
    'Animal category': 'first',
    'Species': 'first',
    'Vaccine type': 'first',
    'Number of vaccinated': 'sum',  
    'time': 'first',  
})


pop_poultry_df = pd.read_csv(os.path.join(source_data_path, "poultry/poultry_pop_2024.csv")).loc[:,['Area','Unit','Value','Year','Item','ISO3']]
pop_poultry_df = pop_poultry_df.sort_values('Value').drop_duplicates(subset=['ISO3','Year','Item'], keep='last')
pop_poultry_df['Value']*=1000
pop_poultry_df.rename(columns={'Value':'TOTAL Population'},inplace=True)

pop_poultry_df = (
    pop_poultry_df.groupby(['Area', 'Year','ISO3'], as_index=False)
    .agg({
        'ISO3':'first',
        'Area': 'first',
        'Year': 'first',
        'Unit': 'first',
        'Item': 'first',
        'TOTAL Population': 'sum',  # Aggregate the 'Value' by summing
    })
)
pop_poultry_df.drop(columns=['Item'],inplace=True)


killed_pop_poultry_df = pd.read_csv(os.path.join(source_data_path, "poultry/killed_poultry_pop_2024.csv")).loc[:,['Area','Unit','Value','Year','Item','ISO3']]
killed_pop_poultry_df = killed_pop_poultry_df.sort_values('Value').drop_duplicates(subset=['ISO3','Year','Item'], keep='last')
killed_pop_poultry_df['Value']*=1000
killed_pop_poultry_df.rename(columns={'Value':'TOTAL Slaughtered Population'},inplace=True)
killed_pop_poultry_df = (
    killed_pop_poultry_df.groupby(['Area', 'Year','ISO3'], as_index=False)
    .agg({
        'ISO3':'first',
        'Area': 'first',
        'Year': 'first',
        'Unit': 'first',
        'Item': 'first',
        'TOTAL Slaughtered Population': 'sum',  # Aggregate the 'Value' by summing
    })
)


pop_poultry_df = pop_poultry_df.sort_values('TOTAL Population').drop_duplicates(subset=['ISO3','Year'], keep='last')
killed_pop_poultry_df = killed_pop_poultry_df.sort_values('TOTAL Slaughtered Population').drop_duplicates(subset=['ISO3','Year'], keep='last')


df_start=reduce(lambda  left,right: pd.merge(left,right,on=['ISO3','Year'],
                                                how='left'), [df_start,
                                                             pop_poultry_df.drop(columns=['Unit','Area']),
                                                              killed_pop_poultry_df.drop(columns=['Unit','Area','Item'])])

df_start['Vaccine Coverage Intermediate']=df_start['Number of vaccinated']/(df_start['TOTAL Population']+df_start['TOTAL Slaughtered Population'])

# %%
# Add missing years for each unique combination of Semester, ISO3, Administrative Division, and Disease
def add_missing_years(df):
    group_columns = ["ISO3", "Disease"]

    unique_combinations = df[group_columns].drop_duplicates()
    unique_combinations['Min_Year'] = df.groupby(group_columns)['Year'].transform('min')
    unique_combinations['Max_Year'] = df.groupby(group_columns)['Year'].transform('max')

    all_years = []
    for _, row in unique_combinations.iterrows():
        years = pd.DataFrame({'Year': range(row['Min_Year'], row['Max_Year'] + 1)})
        for col in group_columns:
            years[col] = row[col]
        all_years.append(years)

    all_years_df = pd.concat(all_years, ignore_index=True)

    expanded_df = pd.merge(all_years_df, df, on=group_columns + ['Year'], how='left')

    none_columns = ["Vaccine Coverage Intermediate","Number of vaccinated"]
    for col in none_columns:
        expanded_df[col] = expanded_df[col].where(expanded_df[col].notna(), None)

    ffill_columns = expanded_df.columns.difference(none_columns + ['Year'])

    expanded_df[ffill_columns] = expanded_df.sort_values(by=group_columns + ['Year'])[ffill_columns].ffill()

    expanded_df['Derived_Vaccinated_Method'] = "None"

    return expanded_df




# Interpolate Adjusted_Susceptible and Vaccinated
def interpolate_adjusted_and_cases(df):
    group_columns = ["ISO3", "Disease"]

    def interpolate_group(group):
        group = group.sort_values('Year').reset_index(drop=True)

        interpolated_vaccinated = group['Vaccine Coverage Intermediate'].fillna(value=np.nan).interpolate(method='linear')

        group.loc[interpolated_vaccinated.notna() & group['Vaccine Coverage Intermediate'].isna(), 'Derived_Vaccinated_Method'] = "Adjusted_Vaccinated"

        group['Vaccine Coverage Intermediate'] = interpolated_vaccinated

        group['Number of vaccinated']=group['Vaccine Coverage Intermediate'] *(group['TOTAL Population']+group['TOTAL Slaughtered Population'])

        return group

    return df.groupby(group_columns, group_keys=False).apply(interpolate_group)

# Function to collect years data was used for interpolation
def update_interpolated_upper_year(df):
    group_columns = ["ISO3",  "Disease"]

    def assign_upper_year(group):
        group = group.sort_values('Year').reset_index(drop=True)

        for idx in group[group['Derived_Vaccinated_Method'].notna()].index:
            if group.loc[idx, 'Derived_Vaccinated_Method'] in ["Adjusted_Vaccinated"]:
                # Find the next original (non-interpolated) row by year
                upper_idx = group[(group.index > idx) & (group['Derived_Vaccinated_Method']=='None')].index.min()
                lower_idx = group[(group.index < idx) & (group['Derived_Vaccinated_Method']=='None')].index.max()

                
                if pd.notna(upper_idx):  
                    group.loc[idx, 'interpolated_upper_year'] = int(group.loc[upper_idx, 'Year'])
                else:
                    group.loc[idx, 'interpolated_upper_year'] = None  

                if pd.notna(lower_idx): 
                    group.loc[idx, 'interpolated_lower_year'] = int(group.loc[lower_idx, 'Year'])
                else:
                    group.loc[idx, 'interpolated_lower_year'] = None 
        return group

    return df.groupby(group_columns, group_keys=False).apply(assign_upper_year)


def process_dataframe(df):
    df = add_missing_years(df)  # Add missing years

    #These two columns are filled in incorrectly, need to update them
    df.drop(columns=['TOTAL Population','TOTAL Slaughtered Population'],inplace=True)


    df=reduce(lambda  left,right: pd.merge(left,right,on=['ISO3','Year'],
                                                how='left'), [df,
                                                             pop_poultry_df.drop(columns=['Unit','Area']),
                                                              killed_pop_poultry_df.drop(columns=['Unit','Area','Item'])])

    df = interpolate_adjusted_and_cases(df)  # Interpolate Adjusted_Susceptible and Incidence, update Cases
    df=update_interpolated_upper_year(df)
    return df

# Example usage
df_result = process_dataframe(df_start)

# %%
def generate_year_range(row):
    if pd.notna(row['interpolated_lower_year']) and pd.notna(row['interpolated_upper_year']):
        return f"{int(row['interpolated_lower_year'])}-{int(row['interpolated_upper_year'])}"
    else:
        return str(int(row['Year']))

df_result['Year Range'] = df_result.apply(generate_year_range, axis=1)

# %%
final_dfs=[]

for year in range(2005,2025): 
    
    df2=df_result.copy()
    df2=df2[df2['Year']<=year]
    
    df_sorted = df2.sort_values(['Country', 'Disease', 'Year'], ascending=[True, True, False])

    # Identify the latest available year for each 'Country' and 'Disease'
    latest_years = df_sorted.groupby(['Country', 'Disease'], as_index=False)['Year'].max()
    
    # Filter rows corresponding to the latest year for each 'Country' and 'Disease'
    df_latest = df_sorted.merge(latest_years, on=['Country', 'Disease', 'Year'])

    cols_keep=['ISO3','Country','Year','Region','Disease','Animal category','Species','Vaccine type','Number of vaccinated','time',
               'Year Range','TOTAL Population','TOTAL Slaughtered Population','Derived_Vaccinated_Method']
    
    df_coverage=df_latest.loc[:,cols_keep]

    df_coverage.reset_index(drop=True, inplace=True)
    
    df_coverage['Year']=[year]*len(df_coverage)
    
    df_coverage['Vaccine Coverage']=df_coverage['Number of vaccinated']/(df_coverage['TOTAL Population']+df_coverage['TOTAL Slaughtered Population'])
    df_coverage['Vaccine Coverage']=[i if i<=1 else 1 if i==i else np.nan for i in df_coverage['Vaccine Coverage']]
    df_coverage['Source'] = df_coverage['Derived_Vaccinated_Method'].apply(
        lambda x: 'WAHIS country-level report; FAOSTAT (linear interpolation between years)' if x != 'None' else 'WAHIS country-level report; FAOSTAT'
    )
    df_coverage.drop(columns=['Derived_Vaccinated_Method'],inplace=True)

    
    df_coverage=df_coverage[df_coverage['Vaccine Coverage']>=0] 
    
    VC_lower=[]
    VC_upper=[]
    
    for row in df_coverage.iterrows():
            l,u=binomtest(int(round(row[1]['Vaccine Coverage']*(row[1]['TOTAL Population']+row[1]['TOTAL Slaughtered Population']))),int(round((row[1]['TOTAL Population']+row[1]['TOTAL Slaughtered Population'])))).proportion_ci()
            VC_lower+=[l]
            VC_upper+=[u]
    
    df_coverage['Vaccine Coverage Lower']=VC_lower
    df_coverage['Vaccine Coverage Upper']=VC_upper
    
    df_part=df_part_full.copy()
    
    df_part=df_part[df_part['Year']<=year]
    
    df_part=df_part.drop_duplicates(subset=['Disease', 'Country'], keep='last')
    
    
    codes_part = [countries.get(country, 'Unknown code:'+country) for country in df_part['Country']]
    
    for code in codes_part:
        if "Unknown" in code:
            print("FIX THIS:",code)
        
    iso3s_part=[]
    
    for i in df_part['Country']:
        try:
            iso3s_part+=[countries[i]]
        except:
            iso3s_part+=[None]
    
    df_part['ISO3']=iso3s_part
    
    #print(np.unique(codes_part))
    
    index_keep=[]
    
    for row in df_part.iterrows():
        if (row[1]['Disease'] not in df_coverage[df_coverage['ISO3']==row[1]['ISO3']]['Disease'].values):
            index_keep+=[row[0]]
    df_part=df_part.loc[index_keep] 
    df_part['Vaccine Coverage']=[i if i<=1 else 1 if i==i else np.nan for i in df_part['Vaccine Coverage']]
    df_part=df_part[df_part['Vaccine Coverage']>=0]
    
    VC_lower=[]
    VC_upper=[]
    
    for row in df_part.iterrows():
            l,u=binomtest(int(round(row[1]['Vaccine Coverage']*(row[1]['Adjusted_Susceptible']))),int(round(row[1]['Adjusted_Susceptible']))).proportion_ci()
            VC_lower+=[l]
            VC_upper+=[u]
    
    df_part['Vaccine Coverage Lower']=VC_lower
    df_part['Vaccine Coverage Upper']=VC_upper
    
    add_to_coverage_df=[]
    
    for row in df_part.iterrows():
       
        if row[1]['Derived_Vaccinated_Method']!='None':
            add_to_coverage_df+=[[row[1]['ISO3'],row[1]['Country'],year,None,
                             row[1]['Disease'], None, None,None,
                     None, None,  row[1]['Year Range'], None, None,
                             row[1]['Vaccine Coverage'],
                     'WAHIS administrative division reports (includes linear interpolation)',row[1]['Vaccine Coverage Lower'],
                     row[1]['Vaccine Coverage Upper']]]    

        else:
            add_to_coverage_df+=[[row[1]['ISO3'],row[1]['Country'],year,None,
                             row[1]['Disease'], None, None,None,
                     None, None,  row[1]['Year Range'], None, None,
                             row[1]['Vaccine Coverage'],
                     'WAHIS administrative division reports',row[1]['Vaccine Coverage Lower'],
                     row[1]['Vaccine Coverage Upper']]]    
   
    add_to_coverage_df = pd.DataFrame(data=add_to_coverage_df,columns=df_coverage.columns)
    
    df_coverage = pd.concat([df_coverage, add_to_coverage_df], ignore_index=True)
    



    final_dfs+=[df_coverage]

    print(year, 'finished analysis')
# Out:
# 2005 finished analysis
# 2006 finished analysis
# 2007 finished analysis
# 2008 finished analysis
# 2009 finished analysis
# 2010 finished analysis
# 2011 finished analysis
# 2012 finished analysis
# 2013 finished analysis
# 2014 finished analysis
# 2015 finished analysis
# 2016 finished analysis
# 2017 finished analysis
# 2018 finished analysis
# 2019 finished analysis
# 2020 finished analysis
# 2021 finished analysis
# 2022 finished analysis
# 2023 finished analysis
# 2024 finished analysis

# %%
years_data =pd.concat(final_dfs)
years_data=years_data.sort_values(by=['ISO3','Year','Disease','Vaccine Coverage'])
years_data=years_data.drop_duplicates(subset=['ISO3','Year','Disease'],keep='last')

# %%
# New data to replace



data=[
['ARG', 'Argentina',2005,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2005,None,None,0,"Department of Agriculture Animal and Plant Health Inspection Service report",0,0],
['DZA', 'Algeria',2003,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2003,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2004,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2004,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2005,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2005,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2006,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2006,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2007,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2007,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2008,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2008,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2009,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2009,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2010,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2010,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2011,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2011,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2012,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2012,None,None,0,"WOAH country-specific report",0,0],
['DZA', 'Algeria',2013,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2013,None,None,0,"WOAH country-specific report",0,0],
['DNK', 'Denmark',2006,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2006,None,None,0,"Department of Agriculture Animal and Plant Health Inspection Service report",0,0],
['SLB', 'Solomon Islands',1999,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,1999,None,None,0,"Solomon Islands Smallholder Agriculture Study",0,0],
['FJI', 'Fiji',2001,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2001,None,None,0,"Country-specific survey",0,0],
['VUT', 'Vanuatu',2017,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2017,None,None,0,"PVS Gap Analysis of the Veterinary Services (VS) of the Republic of Vanuatu",0,0],
['WSM', 'Samoa',1999,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,1999,None,None,0,"Country-specific survey",0,0],
['GUM', 'Guam',2003,None,'Newcastle disease virus (Inf. with)',None,None,None,None,None,2003,None,None,0,"USDA Report",0,0]]

# %%
usa_poultry_pops=pd.DataFrame(data=[['Broiler',3.7,1.4],['Layer',0.8,0.3]],columns=['Type','Percent','SD'])

# %%
usa_coverage=pd.read_excel(os.path.join(source_data_path,'poultry','FDA USA vaccination coverage.xlsx'))
usa_coverage['Std. error layer']=[float(i.replace('(','').replace(')','').replace('-','').replace('—','')) if i.replace('(','').replace(')','').replace('-','').replace('—','')!='' else 0 for i in usa_coverage['Std. error layer']]
usa_coverage['Std. error broiler']=[abs(i) for i in usa_coverage['Std. error broiler']]
usa_coverage['Disease']=[i.replace('\n',' ') for i in usa_coverage['Disease']]

# %%
def percentile_confidence_interval(data):    
    return(np.percentile(data, 2.5),np.percentile(data, 97.5),np.percentile(data, 50))

# %%
standardize_disease_names=dict()
standardize_disease_names['Infectious laryngotracheitis (ILT)']='Avian infectious laryngotracheitis'
standardize_disease_names['Mycoplasma synoviae (MS)']='Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-)'
standardize_disease_names['Mycoplasma gallisepticum (MG)']='Mycoplasma gallisepticum\xa0(Avian mycoplasmosis) (Inf. with)'
standardize_disease_names['Cholera']='Fowl cholera (-2011)'
standardize_disease_names['Newcastle disease']='Newcastle disease virus (Inf. with)'
standardize_disease_names['Infectious bronchitis']='Avian infectious bronchitis'
standardize_disease_names['Salmonella']='Salmonellosis (S. abortusovis)'
standardize_disease_names['Infectious bursal disease (IBD)']='Infectious bursal disease (Gumboro disease)'
standardize_disease_names['Avian encephalomyelitis']='Avian encephalomyelitis'
standardize_disease_names['E. coli']='Colibacillosis'
standardize_disease_names['Chicken anemia virus']='Chicken infectious anemia'
standardize_disease_names['Reovirus']='Reovirus (inf with)'
standardize_disease_names['Fowl pox']='Fowl pox (-2005)'
standardize_disease_names['Coccidiosis']='Coccidiosis'

# %%
values_add=[]

for row in usa_coverage.iterrows():
    percents=[]
    nsims=1000
    
    disease=row[1]['Disease'].replace('\n',' ')
    
    if disease!='Other vaccines':

        for sim in range(nsims):
            
            total_broiler=random.uniform(3.7-1.4,3.7+1.4)
            total_layer=random.uniform(0.8-0.3,0.8+0.3)
            
            prop_broiler=total_broiler/(total_broiler+total_layer)
            prop_layer=total_layer/(total_broiler+total_layer)
            
            row[1]['Pct broiler']
            
            broiler_percent=random.uniform(row[1]['Pct broiler']-row[1]['Std. error broiler'],row[1]['Pct broiler']+row[1]['Std. error broiler'])
            layer_percent=random.uniform(row[1]['Pct layer']-row[1]['Std. error layer'],row[1]['Pct layer']+row[1]['Std. error layer'])
            
            percents+=[broiler_percent*prop_broiler+layer_percent*prop_layer]
            
        l,u,val=percentile_confidence_interval(percents)
        data+=[["USA", 'United States of America',2010, None, standardize_disease_names[disease],None,None,None,None,None,2010,None,None,val/100,'USDA Survey',l/100,u/100]]

# %%
# Create a DataFrame from the new data
replacement_df = pd.DataFrame(data, columns=years_data.columns)

# Replace rows in the original DataFrame
for _, new_row in replacement_df.iterrows():
    condition = (
        (years_data['Year'] >= new_row['Year']) & 
        (years_data['ISO3'] == new_row['ISO3']) & 
        (years_data['Disease'] == new_row['Disease'])
    )

    if years_data.loc[condition].shape[0] > 0:
        for col in years_data.columns:
            if col=='Year':
                years_data.loc[condition, col]=years_data.loc[condition, col]
            else:
                years_data.loc[condition, col] = new_row[col]
        print(f'Found and replaced values for: {new_row["Country"]} ({new_row["Disease"]})')

    else:
        # Append the new row if no match is found
        for year_add in  range(new_row['Year'], 2025):
            new_row_combined = new_row[0:2].tolist() + [year_add] + new_row[3:].tolist()
            
            years_data = pd.concat(
                [years_data, pd.DataFrame([new_row_combined], columns=years_data.columns)],
                ignore_index=True
            )
            if all(pd.isna(new_row_combined)):
                print(new_row_combined)# Only concatenate if at least one non-NaN value exists

            print(f'Added new row for: {year_add} {new_row["Country"]} ({new_row["Disease"]})')
# Out:
# Added new row for: 2005 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Argentina (Newcastle disease virus (Inf. with))
# Added new row for: 2003 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2004 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2005 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Found and replaced values for: Algeria (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Denmark (Newcastle disease virus (Inf. with))
# Added new row for: 1999 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2000 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2001 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2002 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2003 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2004 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2005 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Solomon Islands (Newcastle disease virus (Inf. with))
# Added new row for: 2001 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2002 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2003 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2004 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2005 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Fiji (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Vanuatu (Newcastle disease virus (Inf. with))
# Added new row for: 1999 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2000 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2001 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2002 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2003 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2004 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2005 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Samoa (Newcastle disease virus (Inf. with))
# Added new row for: 2003 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2004 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2005 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2006 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2007 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2008 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2009 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2010 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2011 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2012 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2013 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2014 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2015 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2016 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2017 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2018 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2019 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2020 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2021 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2022 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2023 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2024 Guam (Newcastle disease virus (Inf. with))
# Added new row for: 2010 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2011 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2012 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2013 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2014 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2015 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2016 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2017 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2018 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2019 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2020 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2021 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2022 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2023 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2024 United States of America (Avian infectious laryngotracheitis)
# Added new row for: 2010 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2011 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2012 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2013 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2014 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2015 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2016 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2017 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2018 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2019 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2020 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2021 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2022 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2023 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2024 United States of America (Mycoplasma synoviae (Avian mycoplasmosis) (Inf. with) (2006-))
# Added new row for: 2010 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2011 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2012 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2013 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2014 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2015 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2016 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2017 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2018 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2019 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2020 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2021 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2022 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2023 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2024 United States of America (Mycoplasma gallisepticum (Avian mycoplasmosis) (Inf. with))
# Added new row for: 2010 United States of America (Fowl cholera (-2011))
# Added new row for: 2011 United States of America (Fowl cholera (-2011))
# Added new row for: 2012 United States of America (Fowl cholera (-2011))
# Added new row for: 2013 United States of America (Fowl cholera (-2011))
# Added new row for: 2014 United States of America (Fowl cholera (-2011))
# Added new row for: 2015 United States of America (Fowl cholera (-2011))
# Added new row for: 2016 United States of America (Fowl cholera (-2011))
# Added new row for: 2017 United States of America (Fowl cholera (-2011))
# Added new row for: 2018 United States of America (Fowl cholera (-2011))
# Added new row for: 2019 United States of America (Fowl cholera (-2011))
# Added new row for: 2020 United States of America (Fowl cholera (-2011))
# Added new row for: 2021 United States of America (Fowl cholera (-2011))
# Added new row for: 2022 United States of America (Fowl cholera (-2011))
# Added new row for: 2023 United States of America (Fowl cholera (-2011))
# Added new row for: 2024 United States of America (Fowl cholera (-2011))
# Added new row for: 2010 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2011 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2012 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2013 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2014 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2015 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2016 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2017 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2018 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2019 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2020 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2021 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2022 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2023 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2024 United States of America (Newcastle disease virus (Inf. with))
# Added new row for: 2010 United States of America (Avian infectious bronchitis)
# Added new row for: 2011 United States of America (Avian infectious bronchitis)
# Added new row for: 2012 United States of America (Avian infectious bronchitis)
# Added new row for: 2013 United States of America (Avian infectious bronchitis)
# Added new row for: 2014 United States of America (Avian infectious bronchitis)
# Added new row for: 2015 United States of America (Avian infectious bronchitis)
# Added new row for: 2016 United States of America (Avian infectious bronchitis)
# Added new row for: 2017 United States of America (Avian infectious bronchitis)
# Added new row for: 2018 United States of America (Avian infectious bronchitis)
# Added new row for: 2019 United States of America (Avian infectious bronchitis)
# Added new row for: 2020 United States of America (Avian infectious bronchitis)
# Added new row for: 2021 United States of America (Avian infectious bronchitis)
# Added new row for: 2022 United States of America (Avian infectious bronchitis)
# Added new row for: 2023 United States of America (Avian infectious bronchitis)
# Added new row for: 2024 United States of America (Avian infectious bronchitis)
# Added new row for: 2010 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2011 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2012 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2013 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2014 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2015 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2016 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2017 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2018 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2019 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2020 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2021 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2022 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2023 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2024 United States of America (Salmonellosis (S. abortusovis))
# Added new row for: 2010 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2011 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2012 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2013 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2014 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2015 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2016 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2017 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2018 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2019 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2020 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2021 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2022 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2023 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2024 United States of America (Infectious bursal disease (Gumboro disease))
# Added new row for: 2010 United States of America (Avian encephalomyelitis)
# Added new row for: 2011 United States of America (Avian encephalomyelitis)
# Added new row for: 2012 United States of America (Avian encephalomyelitis)
# Added new row for: 2013 United States of America (Avian encephalomyelitis)
# Added new row for: 2014 United States of America (Avian encephalomyelitis)
# Added new row for: 2015 United States of America (Avian encephalomyelitis)
# Added new row for: 2016 United States of America (Avian encephalomyelitis)
# Added new row for: 2017 United States of America (Avian encephalomyelitis)
# Added new row for: 2018 United States of America (Avian encephalomyelitis)
# Added new row for: 2019 United States of America (Avian encephalomyelitis)
# Added new row for: 2020 United States of America (Avian encephalomyelitis)
# Added new row for: 2021 United States of America (Avian encephalomyelitis)
# Added new row for: 2022 United States of America (Avian encephalomyelitis)
# Added new row for: 2023 United States of America (Avian encephalomyelitis)
# Added new row for: 2024 United States of America (Avian encephalomyelitis)
# Added new row for: 2010 United States of America (Colibacillosis)
# Added new row for: 2011 United States of America (Colibacillosis)
# Added new row for: 2012 United States of America (Colibacillosis)
# Added new row for: 2013 United States of America (Colibacillosis)
# Added new row for: 2014 United States of America (Colibacillosis)
# Added new row for: 2015 United States of America (Colibacillosis)
# Added new row for: 2016 United States of America (Colibacillosis)
# Added new row for: 2017 United States of America (Colibacillosis)
# Added new row for: 2018 United States of America (Colibacillosis)
# Added new row for: 2019 United States of America (Colibacillosis)
# Added new row for: 2020 United States of America (Colibacillosis)
# Added new row for: 2021 United States of America (Colibacillosis)
# Added new row for: 2022 United States of America (Colibacillosis)
# Added new row for: 2023 United States of America (Colibacillosis)
# Added new row for: 2024 United States of America (Colibacillosis)
# Added new row for: 2010 United States of America (Chicken infectious anemia)
# Added new row for: 2011 United States of America (Chicken infectious anemia)
# Added new row for: 2012 United States of America (Chicken infectious anemia)
# Added new row for: 2013 United States of America (Chicken infectious anemia)
# Added new row for: 2014 United States of America (Chicken infectious anemia)
# Added new row for: 2015 United States of America (Chicken infectious anemia)
# Added new row for: 2016 United States of America (Chicken infectious anemia)
# Added new row for: 2017 United States of America (Chicken infectious anemia)
# Added new row for: 2018 United States of America (Chicken infectious anemia)
# Added new row for: 2019 United States of America (Chicken infectious anemia)
# Added new row for: 2020 United States of America (Chicken infectious anemia)
# Added new row for: 2021 United States of America (Chicken infectious anemia)
# Added new row for: 2022 United States of America (Chicken infectious anemia)
# Added new row for: 2023 United States of America (Chicken infectious anemia)
# Added new row for: 2024 United States of America (Chicken infectious anemia)
# Added new row for: 2010 United States of America (Reovirus (inf with))
# Added new row for: 2011 United States of America (Reovirus (inf with))
# Added new row for: 2012 United States of America (Reovirus (inf with))
# Added new row for: 2013 United States of America (Reovirus (inf with))
# Added new row for: 2014 United States of America (Reovirus (inf with))
# Added new row for: 2015 United States of America (Reovirus (inf with))
# Added new row for: 2016 United States of America (Reovirus (inf with))
# Added new row for: 2017 United States of America (Reovirus (inf with))
# Added new row for: 2018 United States of America (Reovirus (inf with))
# Added new row for: 2019 United States of America (Reovirus (inf with))
# Added new row for: 2020 United States of America (Reovirus (inf with))
# Added new row for: 2021 United States of America (Reovirus (inf with))
# Added new row for: 2022 United States of America (Reovirus (inf with))
# Added new row for: 2023 United States of America (Reovirus (inf with))
# Added new row for: 2024 United States of America (Reovirus (inf with))
# Added new row for: 2010 United States of America (Fowl pox (-2005))
# Added new row for: 2011 United States of America (Fowl pox (-2005))
# Added new row for: 2012 United States of America (Fowl pox (-2005))
# Added new row for: 2013 United States of America (Fowl pox (-2005))
# Added new row for: 2014 United States of America (Fowl pox (-2005))
# Added new row for: 2015 United States of America (Fowl pox (-2005))
# Added new row for: 2016 United States of America (Fowl pox (-2005))
# Added new row for: 2017 United States of America (Fowl pox (-2005))
# Added new row for: 2018 United States of America (Fowl pox (-2005))
# Added new row for: 2019 United States of America (Fowl pox (-2005))
# Added new row for: 2020 United States of America (Fowl pox (-2005))
# Added new row for: 2021 United States of America (Fowl pox (-2005))
# Added new row for: 2022 United States of America (Fowl pox (-2005))
# Added new row for: 2023 United States of America (Fowl pox (-2005))
# Added new row for: 2024 United States of America (Fowl pox (-2005))
# Added new row for: 2010 United States of America (Coccidiosis)
# Added new row for: 2011 United States of America (Coccidiosis)
# Added new row for: 2012 United States of America (Coccidiosis)
# Added new row for: 2013 United States of America (Coccidiosis)
# Added new row for: 2014 United States of America (Coccidiosis)
# Added new row for: 2015 United States of America (Coccidiosis)
# Added new row for: 2016 United States of America (Coccidiosis)
# Added new row for: 2017 United States of America (Coccidiosis)
# Added new row for: 2018 United States of America (Coccidiosis)
# Added new row for: 2019 United States of America (Coccidiosis)
# Added new row for: 2020 United States of America (Coccidiosis)
# Added new row for: 2021 United States of America (Coccidiosis)
# Added new row for: 2022 United States of America (Coccidiosis)
# Added new row for: 2023 United States of America (Coccidiosis)
# Added new row for: 2024 United States of America (Coccidiosis)

# %%
years_data[years_data['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [ISO3, Country, Year, Region, Disease, Animal category, Species, Vaccine type, Number of vaccinated, time, Year Range, TOTAL Population, TOTAL Slaughtered Population, Vaccine Coverage, Source, Vaccine Coverage Lower, Vaccine Coverage Upper]
# Index: []

# %%
#We are getting vaccination coverage against "Newcastle disease" in general, not honing in explicitly on velogenic
years_data['Disease']=[i if 'Newcastle disease' not in i else 'Newcastle disease' for i in years_data['Disease']]

# Identify duplicate rows based on ['ISO3', 'Year', 'Disease']
duplicates = years_data.duplicated(subset=['ISO3', 'Year', 'Disease'], keep=False)

# For duplicates, keep rows where 'Source' is not equal to "WAHIS administrative division reports"
filtered_duplicates = years_data[duplicates & (years_data['Source'] != "WAHIS administrative division reports")]

# For all non-duplicate rows, just keep them as they are
non_duplicates = years_data[~duplicates]

# Combine non-duplicates with the filtered duplicates
years_data_filtered = pd.concat([non_duplicates, filtered_duplicates]).sort_index(ignore_index=True)

years_data_filtered = years_data_filtered[~((years_data_filtered['ISO3'] == 'SCG') & (years_data_filtered['Year'] > 2006))]

years_data_filtered.to_csv('2005-2024_full_poultry_vaccine_coverage_by_country.csv',index=False)
