# %% [markdown]
# ## Kernel to load: vax_inc_general

# %%
import pandas as pd
import numpy as np
import pycountry
import sys,os,json
from pathlib import Path

# %%
notebook_dir = os.path.dirname(os.getcwd())
source_data_path=os.path.join(notebook_dir, "Common Source Data")
sys.path.append(source_data_path)
from country_codes import countries

# %%
#Countries that had been part of the EU at some point or follow EU vaccination measures
EU_countries=['Austria','Belgium','Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Germany','Greece',
              'Hungary','Ireland','Italy','Latvia','Lithuania','Luxembourg','Malta','Netherlands','Poland','Portugal','Romania','Slovakia',
              'Slovenia','Spain','Sweden','United Kingdom','Isle of Man'] +['Gibraltar','Monaco']
EU_ISO3s=[countries[i] for i in EU_countries]

# %%
cattle_measures=pd.read_csv(os.path.join(source_data_path,'WAHIS data','cattle_control_measures.csv'))
cattle_measures=cattle_measures[cattle_measures['Control measure'].isin(['Official vaccination','Vaccination prohibited'])]
cattle_measures.drop(columns=['Region','Animal Category'],inplace=True)
cattle_measures.rename(columns={'Species':'Animal'},inplace=True)
cattle_measures['Disease']=[i if 'Newcastle' not in i else 'Newcastle disease (velogenic)' for i in cattle_measures['Disease']]
cattle_measures['Animal']='Cattle'
cattle_measures['Country']=['Cabo Verde' if i=='Cabo verde' else i for i in cattle_measures['Country']]
cattle_measures=cattle_measures[(cattle_measures['Country']!='Ceuta')&(cattle_measures['Country']!='Melilla')]
cattle_measures['ISO3']=[countries[country] for country in cattle_measures['Country']]
cattle_measures.drop(columns=['Country'],inplace=True)
cattle_measures.rename(columns={'Control measure':'Official Vaccination Measure'},inplace=True)
cattle_measures['Year Official Vaccination Measure']=cattle_measures['Year']
cattle_measures['Semester']=[i.split('-')[0] for i in cattle_measures['Semester']]
cattle_measures['Semester'] = pd.Categorical(cattle_measures['Semester'], categories=['Jan', 'Jul'], ordered=True)
cattle_measures = cattle_measures.sort_values(by=['Year', 'Disease', 'ISO3', 'Semester'], ascending=[True, True, True, False])
cattle_measures = cattle_measures.drop_duplicates(subset=['Year', 'Disease', 'ISO3'], keep='first')
cattle_measures.drop(columns=['Semester'],inplace=True)


new_data = []

#Getting latest available data up to the year (takes care of instances were interpolations could not be made, 
    #but past data is available)
for year in range(2005, 2026):
    current_year_data = cattle_measures[cattle_measures['Year'] == year]

    previous_years_data = cattle_measures[cattle_measures['Year'] <= year]

    for _, group in previous_years_data.groupby(['ISO3', 'Disease', 'Animal']):
        #Find the latest available data (row) up to and including the current year
        latest_row = group[group['Year'] == group['Year'].max()].iloc[0]
        
        # If data for the current year is available, keep it
        if not current_year_data.empty and ((current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])).any():
            current_row = current_year_data[(current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])]
            new_data.append(current_row.iloc[0].to_dict())
        else:
            new_row = latest_row.copy()
            new_row['Year'] = year
            new_data.append(new_row.to_dict())

cattle_official_vacc_status_df= pd.DataFrame(new_data)

cattle_official_vacc_status_df['Source']='WAHIS officially reported vaccination measure'

# %%
# Reconciling bTB and mycTB categories (bTB was phased-out and replaced with mycTB after 2018)

old_name = 'Bovine tuberculosis (-2018)'
new_name = 'Mycobacterium tuberculosis complex (Inf. with)(2019-)'

m_old = (cattle_official_vacc_status_df['Disease'].eq(old_name)) & (cattle_official_vacc_status_df['Year'] < 2019)
m_new = (cattle_official_vacc_status_df['Disease'].eq(new_name)) & (cattle_official_vacc_status_df['Year'] > 2018)

btb2myco = cattle_official_vacc_status_df.loc[m_old].copy()
btb2myco['Disease'] = new_name
btb2myco['Source'] = (
    "Reconciled with 'Bovine tuberculosis (-2018)': "
    + cattle_official_vacc_status_df.loc[btb2myco.index, 'Source'].astype(str).fillna('')
)

myco2btb = cattle_official_vacc_status_df.loc[m_new].copy()
myco2btb['Disease'] = old_name
myco2btb['Source'] = (
    "Reconciled with 'Mycobacterium tuberculosis complex (Inf. with)(2019-)': "
    + cattle_official_vacc_status_df.loc[myco2btb.index, 'Source'].astype(str).fillna('')
)

# Append reconciled rows (preserve original column order)
cols = cattle_official_vacc_status_df.columns
cattle_official_vacc_status_df = pd.concat(
    [
        cattle_official_vacc_status_df,
        btb2myco.reindex(columns=cols),
        myco2btb.reindex(columns=cols),
    ],
    ignore_index=True
)

# keep only the row with the latest 'Year Official Vaccination Measure'
keys = ['ISO3', 'Disease', 'Year']
measure_col = 'Year Official Vaccination Measure'

df = cattle_official_vacc_status_df.copy()
df[measure_col] = pd.to_numeric(df[measure_col], errors='coerce')
df = df.sort_values(keys + [measure_col], na_position='first')
df = df.drop_duplicates(subset=keys, keep='last')

cattle_official_vacc_status_df = df

# %%
#ACcounting for bTB prohibition in EU cattle since 1977
cols = ["Year","Disease","Animal","Official Vaccination Measure","ISO3","Year Official Vaccination Measure","Source"]
years = range(2005, 2026)  # change to 2025 for exactly 20 rows/country

#Replacing prohibition reports by WAHIS
cattle_official_vacc_status_df=cattle_official_vacc_status_df[~((cattle_official_vacc_status_df['ISO3'].isin(EU_ISO3s))&(cattle_official_vacc_status_df['Year']>1977)&
                                 ((cattle_official_vacc_status_df['Disease'].isin(["Bovine tuberculosis (-2018)","Mycobacterium tuberculosis complex (Inf. with)(2019-)"]))))]

btb_cattle_add = pd.DataFrame(
    [(y, "Bovine tuberculosis (-2018)", "Cattle","Vaccination prohibited", iso, 1977, "Official vaccination prohibited: https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=CELEX:31978L0052:EN:HTML")
     for iso in EU_ISO3s for y in years],
    columns=cols
)

mtb_cattle_add = pd.DataFrame(
    [(y, "Mycobacterium tuberculosis complex (Inf. with)(2019-)", "Cattle", "Vaccination prohibited", iso, 1977, "Official vaccination prohibited: https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=CELEX:31978L0052:EN:HTML")
     for iso in EU_ISO3s for y in years],
    columns=cols
)

mtb_cattle_add.loc[
    (mtb_cattle_add['ISO3'] == 'GBR') | (mtb_cattle_add['ISO3'] == 'IMN') & (mtb_cattle_add['Year'] > 2020),
    ['Source', 'Year Official Vaccination Measure']
] = ['https://www.legislation.gov.uk/uksi/2021/1001?', 2021]


#UK separated from EU in 2020
btb_cattle_add.loc[
    (btb_cattle_add['ISO3'] == 'GBR' )| (btb_cattle_add['ISO3'] == 'IMN') & (btb_cattle_add['Year'] > 2020),
    ['Source', 'Year Official Vaccination Measure']
] = ['https://www.legislation.gov.uk/uksi/2021/1001?', 2021]


cattle_official_vacc_status_df = pd.concat([cattle_official_vacc_status_df, btb_cattle_add,mtb_cattle_add], ignore_index=True)

# %%
swine_measures=pd.read_csv(os.path.join(source_data_path,'WAHIS data','swine_control_measures.csv'))
swine_measures=swine_measures[swine_measures['Control measure'].isin(['Official vaccination','Vaccination prohibited'])]
swine_measures.drop(columns=['Region','Animal Category'],inplace=True)
swine_measures.rename(columns={'Species':'Animal'},inplace=True)
swine_measures['Disease']=[i if 'Newcastle' not in i else 'Newcastle disease (velogenic)' for i in swine_measures['Disease']]
swine_measures['Animal']='Swine'
swine_measures['Country']=['Cabo Verde' if i=='Cabo verde' else i for i in swine_measures['Country']]
swine_measures=swine_measures[(swine_measures['Country']!='Ceuta')&(swine_measures['Country']!='Melilla')]
swine_measures['ISO3']=[countries[country] for country in swine_measures['Country']]
swine_measures.drop(columns=['Country'],inplace=True)
swine_measures.rename(columns={'Control measure':'Official Vaccination Measure'},inplace=True)
swine_measures['Year Official Vaccination Measure']=swine_measures['Year']
swine_measures['Semester']=[i.split('-')[0] for i in swine_measures['Semester']]
swine_measures['Semester'] = pd.Categorical(swine_measures['Semester'], categories=['Jan', 'Jul'], ordered=True)
swine_measures = swine_measures.sort_values(by=['Year', 'Disease', 'ISO3', 'Semester'], ascending=[True, True, True, False])
swine_measures = swine_measures.drop_duplicates(subset=['Year', 'Disease', 'ISO3'], keep='first')
swine_measures.drop(columns=['Semester'],inplace=True)


new_data = []

#Getting latest available data up to the year (takes care of instances were interpolations could not be made, 
    #but past data is available)
for year in range(2005, 2026):
    current_year_data = swine_measures[swine_measures['Year'] == year]

    previous_years_data = swine_measures[swine_measures['Year'] <= year]

    for _, group in previous_years_data.groupby(['ISO3', 'Disease', 'Animal']):
        #Find the latest available data (row) up to and including the current year
        latest_row = group[group['Year'] == group['Year'].max()].iloc[0]

        # If data for the current year is available, keep it
        if not current_year_data.empty and ((current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])).any():
            current_row = current_year_data[(current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])]
            new_data.append(current_row.iloc[0].to_dict())
        else:
            new_row = latest_row.copy()
            new_row['Year'] = year
            new_data.append(new_row.to_dict())

swine_official_vacc_status_df= pd.DataFrame(new_data)

swine_official_vacc_status_df['Source']='WAHIS - officially reported vaccination measure'

# %%
# Reconciling bTB and mycTB categories (bTB was phased-out and replaced with mycTB after 2018)

old_name = 'Bovine tuberculosis (-2018)'
new_name = 'Mycobacterium tuberculosis complex (Inf. with)(2019-)'

m_old = (swine_official_vacc_status_df['Disease'].eq(old_name)) & (swine_official_vacc_status_df['Year'] < 2019)
m_new = (swine_official_vacc_status_df['Disease'].eq(new_name)) & (swine_official_vacc_status_df['Year'] > 2018)

btb2myco = swine_official_vacc_status_df.loc[m_old].copy()
btb2myco['Disease'] = new_name
btb2myco['Source'] = (
    "Reconciled with 'Bovine tuberculosis (-2018)': "
    + swine_official_vacc_status_df.loc[btb2myco.index, 'Source'].astype(str).fillna('')
)

myco2btb = swine_official_vacc_status_df.loc[m_new].copy()
myco2btb['Disease'] = old_name
myco2btb['Source'] = (
    "Reconciled with 'Mycobacterium tuberculosis complex (Inf. with)(2019-)': "
    + swine_official_vacc_status_df.loc[myco2btb.index, 'Source'].astype(str).fillna('')
)

# Append reconciled rows 
cols = swine_official_vacc_status_df.columns
swine_official_vacc_status_df = pd.concat(
    [
        swine_official_vacc_status_df,
        btb2myco.reindex(columns=cols),
        myco2btb.reindex(columns=cols),
    ],
    ignore_index=True
)

#keep only the row with the latest 'Year Official Vaccination Measure' 
keys = ['ISO3', 'Disease', 'Year']
measure_col = 'Year Official Vaccination Measure'

df = swine_official_vacc_status_df.copy()
df[measure_col] = pd.to_numeric(df[measure_col], errors='coerce')
df = df.sort_values(keys + [measure_col], na_position='first')
df = df.drop_duplicates(subset=keys, keep='last')

swine_official_vacc_status_df = df

# %%
#Accounting for bTB prohibition in EU swine since 2023, and UK/Isle of Man initiatives in 2021
cols = ["Year","Disease","Animal","Official Vaccination Measure","ISO3","Year Official Vaccination Measure","Source"]
years = range(2023, 2026)  # change to 2025 for exactly 20 rows/country


#Replacing below WAHIS declarations with EU/UK declarations
swine_official_vacc_status_df=swine_official_vacc_status_df[~((swine_official_vacc_status_df['ISO3'].isin(EU_ISO3s))&
                                                              (swine_official_vacc_status_df['Year']>2020)&
                                                              (swine_official_vacc_status_df['Disease'].isin([ "Bovine tuberculosis (-2018)",
                                                                                                             "Mycobacterium tuberculosis complex (Inf. with)(2019-)"]))
                                                             )]

swine_official_vacc_status_df=swine_official_vacc_status_df[~((swine_official_vacc_status_df['ISO3'].isin(['GBR','IMN']))&
                                                              (swine_official_vacc_status_df['Year']>2022)&
                                                              (swine_official_vacc_status_df['Disease'].isin([ "Bovine tuberculosis (-2018)",
                                                                                                             "Mycobacterium tuberculosis complex (Inf. with)(2019-)"]))
                                                             )]

btb_swine = pd.DataFrame(
    [(y, "Bovine tuberculosis (-2018)", "Pigs", 'Vaccination prohibited', iso, 2023, "Official vaccination prohibited: https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=CELEX:31978L0052:EN:HTML")
     for iso in [c for c in EU_ISO3s if c not in ['GBR','IMN']] for y in years],
    columns=cols
)

btb_swine_UK = pd.DataFrame(
    [(y, "Bovine tuberculosis (-2018)", "Pigs", 'Vaccination prohibited', iso, 2021, "Official vaccination prohibited: https://www.legislation.gov.uk/uksi/2021/1001?")
     for iso in ['GBR','IMN'] for y in range(2021,2026)],
    columns=cols
)

mtb_swine = pd.DataFrame(
    [(y, "Mycobacterium tuberculosis complex (Inf. with)(2019-)", "Pigs", 'Vaccination prohibited', 
      iso, 2023, "Official vaccination prohibited: https://eur-lex.europa.eu/LexUriServ/LexUriServ.do?uri=CELEX:31978L0052:EN:HTML")
     for iso in [c for c in EU_ISO3s if c not in ['GBR','IMN']] for y in years],
    columns=cols)
    
mtb_swine_UK = pd.DataFrame(
    [(y, "Mycobacterium tuberculosis complex (Inf. with)(2019-)", "Pigs", 'Vaccination prohibited', 
      iso, 2021, "Official vaccination prohibited: https://www.legislation.gov.uk/uksi/2021/1001?")
     for iso in ['GBR','IMN'] for y in range(2021,2026)],
    columns=cols)


swine_official_vacc_status_df = pd.concat([swine_official_vacc_status_df, btb_swine,
                                            btb_swine_UK, mtb_swine, mtb_swine_UK], ignore_index=True)

# %%
poultry_measures=pd.read_csv(os.path.join(source_data_path,'WAHIS data','poultry_control_measures.csv'))
#Correcting misfiled reports
poultry_measures.loc[poultry_measures['Disease']=='Influenza A viruses of high pathogenicity (Inf. with) (non-poultry including wild birds) (2017-)',
                     'Disease']='High pathogenicity avian influenza viruses (poultry) (Inf. with)'
poultry_measures=poultry_measures[poultry_measures['Control measure'].isin(['Official vaccination','Vaccination prohibited'])]
poultry_measures.drop(columns=['Region','Animal Category'],inplace=True)
poultry_measures.rename(columns={'Species':'Animal'},inplace=True)
poultry_measures['Disease']=[i if 'Newcastle' not in i else 'Newcastle disease (velogenic)' for i in poultry_measures['Disease']]
poultry_measures['Animal']='Poultry'
poultry_measures=poultry_measures[(poultry_measures['Country']!='Ceuta')&(poultry_measures['Country']!='Melilla')]
poultry_measures['ISO3']=[countries[country] for country in poultry_measures['Country']]
poultry_measures.drop(columns=['Country'],inplace=True)
poultry_measures.rename(columns={'Control measure':'Official Vaccination Measure'},inplace=True)
poultry_measures['Year Official Vaccination Measure']=poultry_measures['Year']
poultry_measures['Semester']=[i.split('-')[0] for i in poultry_measures['Semester']]
poultry_measures['Semester'] = pd.Categorical(poultry_measures['Semester'], categories=['Jan', 'Jul'], ordered=True)
poultry_measures = poultry_measures.sort_values(by=['Year', 'Disease', 'ISO3', 'Semester'], ascending=[True, True, True, False])
poultry_measures = poultry_measures.drop_duplicates(subset=['Year', 'Disease', 'ISO3'], keep='first')
poultry_measures.drop(columns=['Semester'],inplace=True)


new_data = []

#Getting latest available data up to the year (takes care of instances were interpolations could not be made, 
    #but past data is available)
for year in range(2005, 2026):
    current_year_data = poultry_measures[poultry_measures['Year'] == year]

    previous_years_data = poultry_measures[poultry_measures['Year'] <= year]

    for _, group in previous_years_data.groupby(['ISO3', 'Disease', 'Animal']):
        #Find the latest available data (row) up to and including the current year
        latest_row = group[group['Year'] == group['Year'].max()].iloc[0]

        # If data for the current year is available, keep it
        if not current_year_data.empty and ((current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])).any():
            current_row = current_year_data[(current_year_data['ISO3'] == latest_row['ISO3']) & 
                                            (current_year_data['Disease'] == latest_row['Disease']) & 
                                            (current_year_data['Animal'] == latest_row['Animal'])]
            new_data.append(current_row.iloc[0].to_dict())
        else:
            new_row = latest_row.copy()
            new_row['Year'] = year
            new_data.append(new_row.to_dict())

poultry_official_vacc_status_df= pd.DataFrame(new_data)

poultry_official_vacc_status_df['Source']='WAHIS - officially reported vaccination measure'

# %%
# Reconciling old and new low path avian influenza categories (one was phased-out and replaced with the other after 2021)

old_name = 'Low pathogenic avian influenza (poultry) (2006-2021)'
new_name = 'Low pathogenicity avian influenza viruses transmissible to humans (Inf. with) (2022-)'

m_old = (poultry_official_vacc_status_df['Disease'].eq(old_name)) & (poultry_official_vacc_status_df['Year'] < 2022)
m_new = (poultry_official_vacc_status_df['Disease'].eq(new_name)) & (poultry_official_vacc_status_df['Year'] > 2021)

avold2avnew = poultry_official_vacc_status_df.loc[m_old].copy()
avold2avnew['Disease'] = new_name
avold2avnew['Source'] = (
    "Reconciled with 'Low pathogenic avian influenza (poultry) (2006-2021)': "
    + poultry_official_vacc_status_df.loc[avold2avnew.index, 'Source'].astype(str).fillna('')
)

avnew2avold = poultry_official_vacc_status_df.loc[m_new].copy()
avnew2avold['Disease'] = old_name
avnew2avold['Source'] = (
    "Reconciled with 'Low pathogenicity avian influenza viruses transmissible to humans (Inf. with) (2022-)': "
    + poultry_official_vacc_status_df.loc[avnew2avold.index, 'Source'].astype(str).fillna('')
)

# Append reconciled rows 
cols = poultry_official_vacc_status_df.columns
poultry_official_vacc_status_df = pd.concat(
    [poultry_official_vacc_status_df,
     avold2avnew.reindex(columns=cols),
     avnew2avold.reindex(columns=cols)],
    ignore_index=True
)


# keep only the row with the latest 'Year Official Vaccination Measure' 
keys = ['ISO3', 'Disease', 'Year']
measure_col = 'Year Official Vaccination Measure'

df = poultry_official_vacc_status_df.copy()
df[measure_col] = pd.to_numeric(df[measure_col], errors='coerce')
df = df.sort_values(keys + [measure_col], na_position='first')
df = df.drop_duplicates(subset=keys, keep='last')

poultry_official_vacc_status_df = df

# %%
all_official_vacc_status=pd.concat([cattle_official_vacc_status_df,swine_official_vacc_status_df,poultry_official_vacc_status_df])
all_official_vacc_status['Animal']=['Pigs' if i=='Swine' else i for i in all_official_vacc_status['Animal']]

# %%
imputed_df=pd.read_csv("FINAL_ALL_vaccine_cov_imputations_to_add.csv").drop_duplicates() #China was duplicated, likely due to two listing names designations for China, with same ISO3
imputed_df.drop(columns=['Vaccination Coverage Lower (Residual Only)','Vaccination Coverage Upper (Residual Only)',
                        'Vaccination Coverage Lower (Bootstrap Only)','Vaccination Coverage Upper (Bootstrap Only)'],inplace=True)
imputed_df.rename(columns={'Vaccination Coverage Lower (Asymmetric)':'Vaccination Coverage Lower',
                           'Vaccination Coverage Upper (Asymmetric)':'Vaccination Coverage Upper'},inplace=True)


poultry_original=pd.read_csv("2005-2025_full_poultry_vaccine_coverage_by_country.csv")
poultry_original['Animal']='Poultry'
poultry_original.drop(columns=['poultry_lifespan'],inplace=True)
poultry_original.loc[poultry_original['Source'] == 'USDA Survey', 'Source'] = 'USDA Survey: https://www.aphis.usda.gov/sites/default/files/poultry10_dr_breeder.pdf'


cattle_original=pd.read_csv("2005-2025_full_cattle_vaccine_coverage_by_country.csv")
cattle_original['Animal']='Cattle'
cattle_original.drop(columns=['cattle_lifespan'],inplace=True)
cattle_original.loc[cattle_original['Source'] == 'USDA Survey', 'Source'] = 'USDA Survey: https://www.aphis.usda.gov/sites/default/files/beef-2017-part2.pdf'


swine_original=pd.read_csv("2005-2025_full_swine_vaccine_coverage_by_country.csv")
swine_original['Animal']='Swine'


def duplicate_and_modify(df, disease, new_disease):
    clone_df = df[(df['Disease'] == disease) & (df['ISO3'] != 'USA')].copy()
    clone_df['Disease'] = new_disease
    return pd.concat([df, clone_df], ignore_index=True)


#We are doing below because each country vaccinates against Newcastle disease, USA is the only one we have data for (from an outside source, not WAHIS) that we know doesn't vaccinate against velogenic
    #All other data is either from WAHIS (all velogenic data for Newcastle), or surveys based on velogenic Newcastle
poultry_original = duplicate_and_modify(poultry_original, "Newcastle disease", "Newcastle disease (velogenic)")
cattle_original = duplicate_and_modify(cattle_original, "Newcastle disease", "Newcastle disease (velogenic)")
swine_original = duplicate_and_modify(swine_original, "Newcastle disease", "Newcastle disease (velogenic)")


orginal_dfs=pd.concat([poultry_original, cattle_original, swine_original])

orginal_dfs['ISO3']=[countries[country] for country in orginal_dfs['Country']]

orginal_dfs = orginal_dfs.rename(columns={col: col.replace('Vaccine', 'Vaccination') for col in orginal_dfs.columns})
imputed_df= imputed_df.rename(columns={col: col.replace('Vaccine', 'Vaccination') for col in imputed_df.columns})
compiled=pd.concat([orginal_dfs,imputed_df])

compiled['Vaccination Coverage']=compiled['Vaccination Coverage']*100
compiled['Vaccination Coverage Lower']=compiled['Vaccination Coverage Lower']*100
compiled['Vaccination Coverage Upper']=compiled['Vaccination Coverage Upper']*100
compiled.drop(columns=['Region','Animal category','Species','Vaccination type','Number of vaccinated',
                      'time','TOTAL Population','TOTAL Slaughtered Population'],inplace=True)
compiled.rename(columns={'Vaccination Coverage':'Vaccination Coverage (%)'},inplace=True)

compiled['Animal']=[i if i!='Swine' else 'Pigs' for i in compiled['Animal']]

# %%
disease_animals_unique = pd.concat([compiled,all_official_vacc_status])[['Disease','Animal']].drop_duplicates()
disease_animals_unique['Animal']=[i if i!='Swine' else 'Pigs' for i in disease_animals_unique['Animal'] ]

# %%
# Read the 3rd sheet (index starts at 0, so 2 = 3rd sheet)
comm_exp_vaccines=pd.read_excel(os.path.join(source_data_path,'Literature data','3Tabs_CountriesDiseaseFreeStatus_and_VaccineAvailability_ForImputations.xlsx'),sheet_name=2)
comm_exp_vaccines['Animal']=[i.split('_')[1].title().replace('Swine','Pigs') for i in comm_exp_vaccines['Disease']]
comm_exp_vaccines['Disease']=[i.split('_')[0] for i in comm_exp_vaccines['Disease']]
comm_exp_vaccines.drop(columns=['Source'],inplace=True)

# %%
vacc_filter=pd.read_csv(os.path.join(source_data_path,'Processed data','Multisource','vaccination_filter.csv'))
vacc_filter = vacc_filter.merge(
    pd.DataFrame({'Animal': ['Cattle', 'Pigs', 'Poultry']}),
    how='cross'
)
vacc_filter = vacc_filter.merge(
    pd.DataFrame(disease_animals_unique, columns=["Disease","Animal"]),
    on=["Disease","Animal"], how="inner"
)
vacc_filter=vacc_filter.merge(comm_exp_vaccines,how='left',on=['Animal','Disease'])

# %%
flipped_dict = {v: k for k, v in countries.items()}
flipped_dict['TUR']='Türkiye, Republic of'
flipped_dict['XKX']='Kosovo'

# %%
compiled['Country']=[flipped_dict[iso3] for iso3 in compiled['ISO3']]
compiled = compiled[~((compiled['Country'] == 'Serbia and Montenegro') & (compiled['Year'] > 2006))]

# %%
full_vaccination_final=pd.merge(compiled,all_official_vacc_status,how='outer',on=['ISO3','Year','Disease','Animal'])
full_vaccination_final['Country']=[flipped_dict[i] for i in full_vaccination_final['ISO3']]
full_vaccination_final['Source'] = (
    full_vaccination_final['Source_x'].fillna(full_vaccination_final['Source_y'])
)
full_vaccination_final.rename(columns={'Year Range':'Year Data'},inplace=True)

# %%
full_vaccination_final=full_vaccination_final.loc[:,['Country','ISO3','Animal','Year','Disease','Vaccination Coverage (%)', 'Source', 'Vaccination Coverage Lower', 'Vaccination Coverage Upper', 'Year Data', 'Official Vaccination Measure', 'Year Official Vaccination Measure']]

# %%
full_vaccination_final.rename(columns={'Vaccination Coverage Lower':'Vaccination Coverage (%) Lower',
                                      'Vaccination Coverage Upper':'Vaccination Coverage (%) Upper'},inplace=True)

# %%
full_vaccination_final["Vaccination Coverage (%)"] = full_vaccination_final["Vaccination Coverage (%)"].clip(upper=100)
full_vaccination_final["Vaccination Coverage (%) Upper"] = full_vaccination_final["Vaccination Coverage (%) Upper"].clip(upper=100)

# %%
sheets=pd.read_excel(os.path.join(source_data_path, 'Literature data','3Tabs_CountriesDiseaseFreeStatus_and_VaccineAvailability_ForImputations.xlsx'),sheet_name=[0,1,2])
disease_free_announced=pd.concat(sheets.values(),ignore_index=True)
disease_free_announced['ISO3'] = [countries.get(c, 'not found')
                                  for c in disease_free_announced['Country']]

# %%
#Here we use notes of vaccination status extracted in the literature to fill in any last missing holes
full = full_vaccination_final.copy()
dfa  = disease_free_announced.copy()

for col in ["Date", "Date From"]:
    dfa[col] = pd.to_datetime(dfa[col], errors="coerce")
dfa["eff_year"] = dfa["Date From"].combine_first(dfa["Date"]).dt.year

# Keep only "Vaccination NOT Practiced" == 1 & valid year
vnp = pd.to_numeric(dfa["Vaccination NOT Practiced"], errors="coerce").fillna(0).astype(int)
dfa = dfa.loc[vnp.eq(1) & dfa["eff_year"].notna(), ["ISO3", "Disease", "Source", "eff_year"]].copy()

for df_ in (full, dfa):
    df_["ISO3"] = df_["ISO3"].astype(str).str.strip()
    df_["Disease"] = df_["Disease"].astype(str).str.strip()

full["Year"] = pd.to_numeric(full["Year"], errors="coerce")

# Track original order
full["_rowid"] = np.arange(len(full))

# Attach all candidate DFA rows (same ISO3 & Disease), then keep only<= Year
dfa_ren = dfa.rename(columns={"Source": "_dfa_source", "eff_year": "_dfa_eff_year"})
pairs = full.merge(dfa_ren, on=["ISO3", "Disease"], how="left")

valid = (
    pairs["_dfa_eff_year"].notna() &
    pairs["Year"].notna() &
    (pairs["_dfa_eff_year"] <= pairs["Year"])
)
pairs_valid = pairs.loc[valid, ["_rowid", "_dfa_source", "_dfa_eff_year"]].copy()

# pick the latest record <= Year ---
best = (
    pairs_valid.sort_values(["_rowid", "_dfa_eff_year"])
               .drop_duplicates("_rowid", keep="last")
)

full = full.merge(best, on="_rowid", how="left")

has_match = full["_dfa_eff_year"].notna()

# Ensusring not "WAHIS" or "prohibited" data
src_ok = ~full["Source"].str.contains(r"WAHIS|prohibited", case=False, na=False)

def nonzero(s):
    snum = pd.to_numeric(s, errors="coerce")
    return snum.notna() & (snum != 0)

cov_ok = (
    nonzero(full["Vaccination Coverage (%)"]) &
    nonzero(full["Vaccination Coverage (%) Lower"]) &
    nonzero(full["Vaccination Coverage (%) Upper"])
)

to_update = has_match & src_ok & cov_ok

cols_to_zero = [
    "Vaccination Coverage (%)",
    "Vaccination Coverage (%) Lower",
    "Vaccination Coverage (%) Upper",
]
full.loc[to_update, cols_to_zero] = 0
full.loc[to_update, "Source"] = full.loc[to_update, "_dfa_source"]
full.loc[to_update, "Year Official Vaccination Measure"] = full.loc[to_update, "_dfa_eff_year"].astype("Int64")
full.loc[to_update, "Official Vaccination Measure"] = "Vaccination not practiced"

full_vaccination_final_updated = (
    full.drop(columns=["_rowid", "_dfa_source", "_dfa_eff_year"], errors="ignore")
        .reset_index(drop=True)
)

print(f"Updated rows: {int(to_update.sum())}")
# Out:
# Updated rows: 87

# %%
#Vaccination inference algorithm
k4 = ['ISO3','Year','Disease','Animal']

vf = vacc_filter.copy()

# 1: Vaccinate == 'No'
no = vf.loc[vf['Vaccinate if vaccine exists and not prohibited'].eq('No'), k4 + ['Source','Year data']]
no_idx = pd.MultiIndex.from_frame(no[k4])
look_no = no.set_index(k4)

comp_idx4 = pd.MultiIndex.from_frame(full_vaccination_final[k4])
m_no = comp_idx4.isin(no_idx)
if m_no.any():
    full_vaccination_final.loc[m_no, ['Vaccination Coverage (%)','Vaccination Coverage (%) Lower','Vaccination Coverage (%) Upper']] = 0
    full_vaccination_final.loc[m_no, 'Source'] = look_no.loc[comp_idx4[m_no], 'Source'].to_numpy()
    full_vaccination_final.loc[m_no, 'Year Data'] = look_no.loc[comp_idx4[m_no], 'Year data'].to_numpy()

miss_no_idx = no_idx.difference(comp_idx4)
if len(miss_no_idx):
    add = look_no.loc[miss_no_idx].reset_index()
    for c in full_vaccination_final.columns:
        if c not in add.columns: add[c] = pd.NA
    add[['Vaccination Coverage (%)','Vaccination Coverage (%) Lower','Vaccination Coverage (%) Upper']] = 0
    full_vaccination_final = pd.concat([full_vaccination_final, add[full_vaccination_final.columns]], ignore_index=True)

# refresh
comp_idx4 = pd.MultiIndex.from_frame(full_vaccination_final[k4])

# 2: Drop imputations if vaccination status unknown
unk_idx_all = pd.MultiIndex.from_frame(vf.loc[
    vf['Vaccinate if vaccine exists and not prohibited'].eq('Unknown'), k4
])
unk_idx = unk_idx_all.difference(no_idx)

if len(unk_idx):
    drop_mask = comp_idx4.isin(unk_idx) & full_vaccination_final['Source'].eq('Imputed')
    if drop_mask.any():
        full_vaccination_final = full_vaccination_final.loc[~drop_mask].reset_index(drop=True)

# refresh 
comp_idx4 = pd.MultiIndex.from_frame(full_vaccination_final[k4])

# No Commercial Vaccine no official vaccination declared to WAHIS
yes_nc_idx_all = pd.MultiIndex.from_frame(vf.loc[
    (vf['Vaccinate if vaccine exists and not prohibited'].eq('Yes')) &
    (vf['Commercial Vaccine'].eq(0)), k4
])
apply3_idx = yes_nc_idx_all.difference(no_idx.union(unk_idx_all))

if len(apply3_idx):  
    # Case/whitespace-robust "Official Vaccination" check
    s = full_vaccination_final['Official Vaccination Measure'].astype(str).str.strip().str.casefold()
    official_is_official = s.eq('official vaccination')

    m3 = (
        comp_idx4.isin(apply3_idx) &
        full_vaccination_final['Source'].eq('Imputed') &
        ~official_is_official
    )

    if m3.any():
        msg = "Inferred no vaccination - no WAHIS reports of vaccination and no commercial vaccine exists"
        full_vaccination_final.loc[m3, ['Vaccination Coverage (%)',
                                        'Vaccination Coverage (%) Lower',
                                        'Vaccination Coverage (%) Upper']] = 0
        full_vaccination_final.loc[m3, 'Source'] = msg
        full_vaccination_final.loc[m3, 'Year Data'] = np.nan  # keep if you want to blank this as in Step 3

# %%
# Zero out coverage where vaccination is prohibited
mask = full_vaccination_final['Official Vaccination Measure'].eq('Vaccination prohibited')
full_vaccination_final.loc[mask, ['Vaccination Coverage (%)',
                                  'Vaccination Coverage Lower',
                                  'Vaccination Coverage Upper']] = 0

# Replace Source for those rows if it doesn't already mention "Official vaccination prohibited"
mask_source = mask & ~full_vaccination_final['Source'].str.contains(
    'Official vaccination prohibited', case=False, na=False
)
full_vaccination_final.loc[mask_source, 'Source'] = "WAHIS 'vaccination prohibited' control measure"

full_vaccination_final.loc[mask, 'Year Data'] = full_vaccination_final.loc[mask, 'Year Official Vaccination Measure']

# %%
#Code to add source for vaccination practice status when imputing vaccination coverage
keys = ['ISO3', 'Year', 'Animal', 'Disease']

vf_yes = (
    vacc_filter.loc[
        vacc_filter['Vaccinate if vaccine exists and not prohibited'].eq('Yes'),
        keys + ['Source']
    ]
    .dropna(subset=['Source'])
    .groupby(keys, as_index=False)['Source'].first()
    .rename(columns={'Source': 'VaccSource'})
)

# Merge to line up the matching vacc_filter Source
merged = full_vaccination_final.merge(vf_yes, on=keys, how='left')

# Append "; <vacc_filter Source> and commercial vaccine exists"  where
# - full_vaccination_final['Source'] == 'Imputed'
# - there is a matching VaccSource
mask = (
    merged['Source'].astype(str).str.strip().eq('Imputed') &
    merged['VaccSource'].notna()
)

merged.loc[mask, 'Source'] = (
    merged.loc[mask, 'Source'].str.strip()
    + '; ' + merged.loc[mask, 'VaccSource'].astype(str).str.strip()
)

# Drop helper column and assign back
full_vaccination_final = merged.drop(columns=['VaccSource'])

# %%
#Taking care of edge case where there was reported official vaccination, but we could not impute due to insufficient total datapoints to meet self-specified imputation requirements
mask = (
    full_vaccination_final['Official Vaccination Measure'].eq('Official vaccination')
    & full_vaccination_final['Vaccination Coverage (%)'].isna()
)

full_vaccination_final.loc[mask, 'Source'] = (
    "WAHIS 'official vaccination' control measure; <30 country imputation threshold for disease"
)

# %%
full_vaccination_final=full_vaccination_final.sort_values(['Country','Animal','Year','Disease'])

# %%
#Accounting for final two cases in whcih source was assigned to WAHIS country level / administrative division report, but value was imputed due to report being associated with other domestic animal type
full_vaccination_final.loc[full_vaccination_final['Source']=='Imputed; WAHIS administrative division report','Source']='Imputed; WAHIS administrative division report in another livestock type'
full_vaccination_final.loc[full_vaccination_final['Source']=='Imputed; WAHIS country level report','Source']='Imputed; WAHIS country level report in another livestock type'

# %%
# Zero out coverage where vaccination is prohibited
mask = full_vaccination_final['Official Vaccination Measure'].eq('Vaccination prohibited')
full_vaccination_final.loc[mask, ['Vaccination Coverage (%)',
                                  'Vaccination Coverage (%) Lower',
                                  'Vaccination Coverage (%) Upper']] = 0

# Replace Source for those rows **only if** it doesn't already mention "Official vaccination prohibited"
mask_source = mask & ~full_vaccination_final['Source'].str.contains(
    'Official vaccination prohibited', case=False, na=False
)
full_vaccination_final.loc[mask_source, 'Source'] = "WAHIS 'vaccination prohibited' control measure"

full_vaccination_final.loc[mask, 'Year Data'] = full_vaccination_final.loc[mask, 'Year Official Vaccination Measure']

# %%
full_vaccination_final = full_vaccination_final.loc[~((full_vaccination_final["Animal"].eq("Poultry")) & (full_vaccination_final["Disease"].eq("Influenza A viruses of high pathogenicity (Inf. with) (non-poultry including wild birds) (2017-)")) & (full_vaccination_final["Source"].astype(str).str.contains("imputed", case=False, na=False))), :].copy()
full_vaccination_final = full_vaccination_final.loc[~((full_vaccination_final["Animal"].eq("Poultry")) & (full_vaccination_final["Disease"].eq("Influenza A viruses of high pathogenicity (Inf. with) (non-poultry including wild birds) (2017-)")) & (full_vaccination_final["Source"].astype(str).str.contains("inferred", case=False, na=False))), :].copy()

# %%
#Inserting general influenza A cateogry (WAHIS collects this) to represent all influenza infections (High path. and low path.)
IAV   = "Influenza A virus (Inf. with)"
OTHERS = [
    "High pathogenicity avian influenza viruses (poultry) (Inf. with)",
    "Influenza A viruses of high pathogenicity (Inf. with) (non-poultry including wild birds) (2017-)",
    "Low pathogenic avian influenza (poultry) (2006-2021)",
    "Low pathogenicity avian influenza viruses transmissible to humans (Inf. with) (2022-)"
]
KEYS = ["ISO3","Animal","Year"]

VC   = "Vaccination Coverage (%)"
VCU  = "Vaccination Coverage Upper"
VCL  = "Vaccination Coverage Lower"
SRC  = "Source"
YD   = "Year Data"

NON_POULTRY_HP = "Influenza A viruses of high pathogenicity (Inf. with) (non-poultry including wild birds) (2017-)"
LP_P           = "Low pathogenic avian influenza (poultry) (2006-2021)"
HP_P           = "High pathogenicity avian influenza viruses (poultry) (Inf. with)"

def reconcile_iav_max(df_in: pd.DataFrame) -> pd.DataFrame:
    df = df_in.copy()

    # 1) Look at other influenza categories
    cand = df[df["Disease"].isin(OTHERS)].copy()
    if cand.empty or VC not in cand.columns:
        return df

    for col in (VC, VCU, VCL):
        if col in cand.columns:
            cand[col] = pd.to_numeric(cand[col], errors="coerce")
    cand = cand[cand[VC].notna()]
    if cand.empty:
        return df

    # best influenza category: max VC (tie-breaker VCU)
    sort_cols = [*KEYS, VC] + ([VCU] if VCU in cand.columns else [])
    sort_asc  = [True, True, True, False] + ([False] if VCU in cand.columns else [])
    donors = (
        cand.sort_values(sort_cols, ascending=sort_asc)
            .drop_duplicates(subset=KEYS, keep="first")
    )

    # 2) Existing IAV rows
    iav = df[df["Disease"].eq(IAV)].copy()
    if not iav.empty:
        iav["_row"] = iav.index
        iav_num = iav.copy()
        iav_num[VC] = pd.to_numeric(iav_num.get(VC), errors="coerce")
        if VCU in iav_num.columns:
            iav_num[VCU] = pd.to_numeric(iav_num[VCU], errors="coerce")
        iav_sort_cols = [*KEYS, VC] + ([VCU] if VCU in iav_num.columns else [])
        iav_sort_asc  = [True, True, True, False] + ([False] if VCU in iav_num.columns else [])
        iav_pick = (
            iav_num.sort_values(iav_sort_cols, ascending=iav_sort_asc)
                   .drop_duplicates(subset=KEYS, keep="first")
        )
    else:
        iav_pick = iav  # empty frame with same columns

    # 3) Merge with chosen infleunza rows and decide updates
    donor_cols = [c for c in [VC, VCU, VCL, SRC, YD, "Disease"] if c in donors.columns]
    merged = iav_pick.merge(
        donors[KEYS + donor_cols].rename(columns={c: f"donor_{c}" for c in donor_cols}),
        on=KEYS, how="left"
    )

    curr_vc  = pd.to_numeric(merged.get(VC), errors="coerce")
    donor_vc = pd.to_numeric(merged.get("donor_" + VC), errors="coerce")
    need_update = donor_vc.notna() & (donor_vc > curr_vc.fillna(-np.inf))  # strictly greater

    # Source info for later assignment
    if SRC in df.columns:
        donor_disease = merged.get("donor_Disease", "").fillna("")
        animal        = merged["Animal"].fillna("")
        add = np.where(
            (donor_disease.eq(NON_POULTRY_HP) & animal.eq("Poultry")) |
            (donor_disease.isin([LP_P, HP_P]) & ~animal.eq("Poultry")),
            " filed for " + animal,
            ""
        )
        donor_src_part = merged.get("donor_" + SRC, "").fillna("").astype(str)
        new_src = (
            'Reconciled: aligned with influenza category with largest coverage: '
        ) + '"' + donor_disease + '"' + add + "; " + donor_src_part

    # Apply updates to IAV if higher val in an influenza category
    if not merged.empty and need_update.any():
        upd_rows = merged.loc[need_update, "_row"].to_numpy()
        df.loc[upd_rows, VC] = donor_vc[need_update].to_numpy()
        if VCU in df.columns and ("donor_" + VCU) in merged.columns:
            df.loc[upd_rows, VCU] = merged.loc[need_update, "donor_" + VCU].to_numpy()
        if VCL in df.columns and ("donor_" + VCL) in merged.columns:
            df.loc[upd_rows, VCL] = merged.loc[need_update, "donor_" + VCL].to_numpy()
        if YD in df.columns and ("donor_" + YD) in merged.columns:
            df.loc[upd_rows, YD] = merged.loc[need_update, "donor_" + YD].to_numpy()
        if SRC in df.columns:
            df.loc[upd_rows, SRC] = new_src[need_update].to_numpy()

    # 4)Insert IAV is not already present
    keys_in_iav = iav[KEYS].drop_duplicates() if not iav.empty else pd.DataFrame(columns=KEYS)
    missing = donors.merge(keys_in_iav, on=KEYS, how="left", indicator=True)
    missing = missing[missing["_merge"].eq("left_only")].drop(columns="_merge")

    if not missing.empty:
        new_rows = missing.copy()
        new_rows["Disease"] = IAV
        if VC in df.columns and VC in new_rows.columns:
            new_rows[VC] = pd.to_numeric(new_rows[VC], errors="coerce")
        if VCU in df.columns and VCU in new_rows.columns:
            new_rows[VCU] = pd.to_numeric(new_rows[VCU], errors="coerce")
        if VCL in df.columns and VCL in new_rows.columns:
            new_rows[VCL] = pd.to_numeric(new_rows[VCL], errors="coerce")
        if SRC in df.columns:
            d_disease = missing["Disease"].fillna("")
            a_animal  = missing["Animal"].fillna("")
            add2 = np.where(
                (d_disease.eq(NON_POULTRY_HP) & a_animal.eq("Poultry")) |
                (d_disease.isin([LP_P, HP_P]) & ~a_animal.eq("Poultry")),
                " filed for " + a_animal,
                ""
            )
            donor_src2 = missing.get(SRC, "").fillna("").astype(str)
            ins_src = (
                'Reconciled: aligned with influenza category with largest coverage: '
            ) + '"' + d_disease + '"' + add2 + "; " + donor_src2
            new_rows[SRC] = ins_src
        if YD in df.columns and YD in new_rows.columns:
            new_rows[YD] = new_rows[YD]

        # append
        new_rows = new_rows.reindex(columns=df.columns, fill_value=np.nan)
        df = pd.concat([df, new_rows], ignore_index=True)

    return df

full_vaccination_final = reconcile_iav_max(full_vaccination_final)

# %%
#Removing imputations for countries that do not report to WAHIS, but had imputations informed via animal population demographics, GDP etc.
countries_dont_report=['Virgin Islands, British',
'Antigua and Barbuda',
'Kosovo',
'Saint Kitts and Nevis',
'Gibraltar',
'Curaçao',
'Macao',
'Virgin Islands, U.S.',
'Saint Martin (French part)',
'Sint Maarten (Dutch part)',
'Tuvalu',
'Guam',
'Isle of Man',
'Monaco',
'Northern Mariana Islands',
'Niue',
'Turks and Caicos Islands',
'Tokelau',
'Bahamas',
'Puerto Rico',
'American Samoa',
'Marshall Islands',
'Nauru',
'Dominica',
'Bermuda']

ISO3s_no_reports=[countries[i] for i in countries_dont_report]

# %%
countries['Serbia and Montenegro']='SCG'

flipped_dict = {v: k for k, v in countries.items()}
flipped_dict['TUR']='Türkiye, Republic of'
flipped_dict['XKX']='Kosovo'

# %%
full_vaccination_final['Country']=[flipped_dict[iso3] for iso3 in full_vaccination_final['ISO3']]

# %%
#Formatting
full_vaccination_final['Year Data']=[i.replace('.0','') if type(i)==str else i for i in full_vaccination_final['Year Data'] ]

# %%
len(full_vaccination_final)
# Out:
# 503030

# %%
full_vaccination_final=full_vaccination_final.sort_values(['Country','Animal','Year','Disease'])

# %%
full_vaccination_final.drop(columns=['Vaccination Coverage Lower','Vaccination Coverage Upper'],inplace=True)

# %%
def load_valid_diseases(path):
    with Path(path).open("r", encoding="utf-8") as f:
        payload = json.load(f)

    data = payload["data"]
    out: Dict[str, Set[str]] = {}
    for animal, diseases in data.items():
        if not isinstance(diseases, list) or not all(isinstance(x, str) for x in diseases):
            raise ValueError("Each value must be a list[str]")
        out[str(animal)] = set(diseases)
    return out

valid_diseases = load_valid_diseases(os.path.join(source_data_path,'Processed data','WAHIS data','disease_animal_sets.json'))
valid_diseases['Cattle'].remove('West Nile Fever') #Cattle do not have vaccine available against West Nile Fever

# %%
# The (Animal, Disease) pairs of interest
valid_pairs = {(animal, d) for animal, ds in valid_diseases.items() for d in ds}

pair_ok = pd.Series(list(zip(full_vaccination_final["Animal"], 
                             full_vaccination_final["Disease"])),
                    index=full_vaccination_final.index).isin(valid_pairs)

has_flag = full_vaccination_final["Source"].astype(str)\
    .str.contains(r"inferred|imputed|administrative division", case=False, na=False) #including administrative division reports of 0, since vaccine obviously doesn't/will never exist anyway.

#Remove unnecessary records
to_remove = (~pair_ok) & has_flag

full_vaccination_final = full_vaccination_final[~to_remove].copy()

# %%
#Adjusting source for diseases reconciled with others (shifting categories via WAHIS reporting, so we reconciled with best match to inform predictions)

mask = (
    (full_vaccination_final['Disease'] == 'Mycobacterium tuberculosis complex (Inf. with)(2019-)') &
    (full_vaccination_final['Year'] < 2019) &
    (~full_vaccination_final['Source'].str.contains('bovine tuberculosis', case=False, na=False))
)

full_vaccination_final.loc[mask, 'Source'] = (
    full_vaccination_final.loc[mask, 'Source'].astype('string')
    + ' (Reconciled with Bovine tuberculosis (-2018))'
)

mask = (
    (full_vaccination_final['Disease'] == 'Bovine tuberculosis (-2018)') &
    (full_vaccination_final['Year'] >= 2019) &
    (~full_vaccination_final['Source'].str.contains('Mycobacterium tuberculosis', case=False, na=False))
)

full_vaccination_final.loc[mask, 'Source'] = (
    full_vaccination_final.loc[mask, 'Source'].astype('string')
    + ' (Reconciled with Mycobacterium tuberculosis complex (Inf. with)(2019-))'
) 
    
mask = (
    (full_vaccination_final['Disease'] == 'Low pathogenic avian influenza (poultry) (2006-2021)') &
    (full_vaccination_final['Year'] >= 2022) &
    (~full_vaccination_final['Source'].str.contains('Low pathogenicity avian influenza', case=False, na=False))
)

full_vaccination_final.loc[mask, 'Source'] = (
    full_vaccination_final.loc[mask, 'Source'].astype('string')
    + ' (Reconciled with Low pathogenicity avian influenza viruses transmissible to humans (Inf. with) (2022-))'
)
    
    
mask = (
    (full_vaccination_final['Disease'] == 'Low pathogenicity avian influenza viruses transmissible to humans (Inf. with) (2022-)') &
    (full_vaccination_final['Year'] < 2022) &
    (~full_vaccination_final['Source'].str.contains('Low pathogenic avian influenza', case=False, na=False))
)

full_vaccination_final.loc[mask, 'Source'] = (
    full_vaccination_final.loc[mask, 'Source'].astype('string')
    + ' (Reconciled with Low pathogenic avian influenza (poultry) (2006-2021))'
)

# %%
full_vaccination_final[~full_vaccination_final['ISO3'].isin(ISO3s_no_reports)].to_csv('Supplementary Spreadsheet- Vaccination Coverage Estimates.csv',index=False,
                                                                                    encoding='utf-8-sig'  # Use 'utf-8-sig' to handle special characters correctly
)
